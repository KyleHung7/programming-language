# %% [markdown]
# <a href="https://colab.research.google.com/github/KyleHung7/programming-language/blob/main/Week_5_Advanced_2024_Q3_Financial_Report_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **2024 Q3 上市公司財報分析**

# %% [markdown]
# #### 1.從google sheet 匯入原始資料

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
import pandas as pd
# read data and put it in a dataframe
# 在 google 工作表載入 gsheets
gsheets = gc.open_by_url('https://docs.google.com/spreadsheets/d/1OlKQx45xvfCgD3TwCSv7yA8cPFv45zhzM8Hr0sUN0_o/edit?usp=sharing')

# %%
from gspread_dataframe import set_with_dataframe

# 選擇要更新的工作表（選擇第一個工作表）
worksheet = gsheets.get_worksheet(0)  # 如果是其他工作表，可以用 get_worksheet(index)

# %%
# 取得 Google Sheets 內容
data = worksheet.get_all_values()  # 取得所有儲存格資料，回傳為 2D 陣列

# 將資料轉換為 DataFrame
df = pd.DataFrame(data)

# %%
df
# Out:
#              0   1                  2               3      4   \
# 0
# 1
# 2                                 營業收入
# 3          公司名稱      Operating Revenue
# 4     Code&Name               113年1-9月        112年1-9月     增減
# ...         ...  ..                ...             ...    ...
# 1126
# 1127             合計     30,264,849,193  26,963,889,905  12.24
# 1128
# 1129
# 1130
#
#                                5              6   \
# 0
# 1
# 2                            營業利益
# 3     Net Operating Income (Loss)
# 4                        113年1-9月       112年1-9月
# ...                           ...            ...
# 1126
# 1127                3,247,242,896  2,350,307,698
# 1128
# 1129
# 1130
#
#                                            7            8   \
# 0
# 1
# 2                                  營業外收入及支出合計
# 3     Total non-operating income and expenses
# 4                                    113年1-9月     112年1-9月
# ...                                       ...          ...
# 1126
# 1127                              386,045,336  420,139,358
# 1128
# 1129
# 1130
#
#                            9   ...             12                  13  \
# 0                  民國113年1-9月  ...
# 1                Jan-Sep 2024  ...
# 2                    稅後淨利(淨損)  ...            本期末           每股盈餘(NT$)
# 3     Profit (Loss) after Tax  ...             股本  Earnings Per Share
# 4                    113年1-9月  ...  Share Capital            113年1-9月
# ...                       ...  ...            ...                 ...
# 1126                           ...
# 1127            2,844,450,578  ...  7,864,057,376                3.67
# 1128                           ...
# 1129                           ...
# 1130                           ...
#
#             14     15     16    17     18                        19  \
# 0
# 1
# 2                 每 股    淨值佔    流動     速動                  稅前淨利(淨損)
# 3                 淨 值    總資產    比率     比率  Profit (Loss) before Tax
# 4     112年1-9月  (NT$)    (%)        Quick                  113年1-9月
# ...        ...    ...    ...   ...    ...                       ...
# 1126
# 1127      2.79  37.57  20.52  1.56   0.93             3,633,288,232
# 1128
# 1129
# 1130
#
#                   20     21
# 0           單位：新臺幣千元
# 1     UNIT：NT$ 1,000
# 2
# 3
# 4           112年1-9月     增減
# ...              ...    ...
# 1126
# 1127   2,770,447,056  31.14
# 1128
# 1129
# 1130
#
# [1131 rows x 22 columns]

# %% [markdown]
# #### 2.原始資料清理

# %%
import pandas as pd

# 設定欄位名稱
expected_columns = [
    "Code_Name", "Company", "Category", "Revenue_2024", "Revenue_Growth", "Revenue_2023",
    "Net_Income_2024", "Net_Income_2023", "Non_Operating_Income", "Non_Operating_Expense",
    "Profit_After_Tax_2024", "Profit_After_Tax_2023", "Share_Capital",
    "EPS_2024", "EPS_2023", "Net_Value", "Net_Value_Growth", "Quick_Ratio",
    "Current_Ratio", "Pre_Tax_Profit_2024", "Pre_Tax_Profit_2023", "Pre_Tax_Profit_Growth",
    "Extra_Column1", "Extra_Column2", "Extra_Column3"
]

# 確保欄位數量匹配
df.columns = expected_columns[:len(df.columns)]

# 轉換 Code_Name 為數字
df["Code_Name"] = pd.to_numeric(df["Code_Name"], errors="coerce")

# 建立 Category 欄位
df["Category"] = pd.NA  # 使用 Pandas NA 類型

# 找出類別行 (Code_Name 在 1-18、20、21-38 之間)
category_rows = df[df["Code_Name"].isin(list(range(1, 19)) + [20] + list(range(21, 39)))]

# 迴圈填充 Category
current_category = None
for index, row in df.iterrows():
    if pd.notna(row["Code_Name"]) and row["Code_Name"] in list(range(1, 19)) + [20] + list(range(21, 39)):
        current_category = row["Company"]
    else:
        df.loc[index, "Category"] = current_category  # 使用 .loc 避免警告

# 過濾掉類別行（確保 copy()，避免 SettingWithCopyWarning）
df = df[~df["Code_Name"].isin(list(range(1, 19)) + [20] + list(range(21, 39)))].copy()

# 轉換 Code_Name 為整數
df = df.dropna(subset=["Code_Name"])
df["Code_Name"] = df["Code_Name"].astype(int)

# 重新索引
df = df.reset_index(drop=True)

# %%
df
# Out:
#       Code_Name Company Category Revenue_2024 Revenue_Growth Revenue_2023  \
# 0          1101      台泥      水泥類   80,966,464          30.41   11,795,129
# 1          1102      亞泥      水泥類   60,239,086          -7.97    4,767,095
# 2          1103      嘉泥      水泥類    2,115,231           4.63      -81,015
# 3          1104      環泥      水泥類    5,627,754           4.37      782,566
# 4          1108      幸福      水泥類    3,689,989          -3.66      469,973
# ...         ...     ...      ...          ...            ...          ...
# 1019       9940    信義房屋      其他類   10,807,808          -3.93    1,643,251
# 1020       9941      裕融      其他類   30,800,878           1.95    5,090,668
# 1021       9942      茂順      其他類    3,657,072         -20.02      732,616
# 1022       9944      新麗      其他類    1,642,565          13.57      170,249
# 1023       9945     潤泰新      其他類   18,682,909          23.18    4,220,161
#
#      Net_Income_2024 Net_Income_2023 Non_Operating_Income  \
# 0          6,596,656       3,525,863            3,943,167
# 1          5,992,893       6,131,943            5,995,078
# 2           -126,554         680,460              276,448
# 3            664,888         576,771            1,379,251
# 4            507,659         -16,691               60,557
# ...              ...             ...                  ...
# 1019       1,657,086         411,054              172,331
# 1020       6,734,102         682,240              291,384
# 1021       1,020,773          41,338               43,441
# 1022         -37,542         -30,864              453,657
# 1023       3,188,768      14,926,340            9,034,016
#
#      Non_Operating_Expense  ... Share_Capital EPS_2024 EPS_2023 Net_Value  \
# 0                7,363,974  ...    77,511,817     0.93     0.82     31.94
# 1                9,087,900  ...    35,465,629     2.72     2.88     50.12
# 2                  517,895  ...     7,902,474     0.79     0.21     32.88
# 3                1,105,588  ...     6,866,818     1.61      2.4     33.91
# 4                  362,658  ...     4,047,380      0.9     1.16     12.45
# ...                    ...  ...           ...      ...      ...       ...
# 1019             1,542,786  ...     7,368,465     2.09     1.84     18.52
# 1020             4,234,030  ...     6,482,250      7.4     9.31      58.1
# 1021               525,722  ...       831,613     6.32     9.41     47.72
# 1022                35,906  ...     1,091,071     0.34     1.71     32.97
# 1023            14,495,303  ...    28,442,251     5.31     3.67      37.3
#
#      Net_Value_Growth Quick_Ratio Current_Ratio Pre_Tax_Profit_2024  \
# 0                42.1        1.99          1.29          15,320,992
# 1               54.06        1.46           0.8          10,899,038
# 2               60.31        4.18          1.53             599,445
# 3               80.09        1.84          0.86           1,359,337
# 4                49.9        1.44          0.35             453,282
# ...               ...         ...           ...                 ...
# 1019            39.39        2.64          0.71           2,054,305
# 1020            12.79           1          0.84           5,772,908
# 1021             78.4        4.94          2.98             773,954
# 1022            55.71        2.06          1.62             139,385
# 1023            54.13        1.28          0.35          19,146,501
#
#      Pre_Tax_Profit_2023 Pre_Tax_Profit_Growth
# 0             10,539,823                 45.36
# 1             11,987,971                 -9.08
# 2                149,894                299.91
# 3              2,044,139                 -33.5
# 4                568,216                -20.23
# ...                  ...                   ...
# 1019           1,829,417                 12.29
# 1020           7,025,486                -17.83
# 1021           1,064,214                -27.27
# 1022             416,115                 -66.5
# 1023          12,222,784                 56.65
#
# [1024 rows x 22 columns]

# %% [markdown]
# #### 3.回傳google sheet 紀錄資料

# %%
from gspread_dataframe import set_with_dataframe

# 選擇要更新的工作表（選擇第一個工作表）
worksheet = gsheets.get_worksheet(1)  # 如果是其他工作表，可以用 get_worksheet(index)

# 將 DataFrame 寫入 Google Sheets
set_with_dataframe(worksheet, df)

# %% [markdown]
# #### 4.繪製長條圖分析

# %%
import pandas as pd
import plotly.express as px

# 確保 Revenue_2024 是數值型態，去掉千分位逗號
df["Revenue_2024"] = df["Revenue_2024"].astype(str).str.replace(",", "").astype(float)

# 先按 2024 年營收排序，取前 10 名
top10_companies = df.nlargest(10, "Revenue_2024")

# 繪製長條圖
fig = px.bar(top10_companies,
             x="Company",
             y="Revenue_2024",
             title="前 10 大企業 2024 年營收比較",
             labels={"Company": "公司名稱", "Revenue_2024": "營收 (NTD)"},
             color="Company")  # 顯示數值

# 顯示圖表
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0ee8a525-2d4e-4450-9bdd-f41789dc708d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ee8a525-2d4e-4450-9bdd-f41789dc708d")) {                    Plotly.newPlot(                        "0ee8a525-2d4e-4450-9bdd-f41789dc708d",                        [{"alignmentgroup":"True","hovertemplate":"公司名稱=%{x}\u003cbr\u003e營收 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"鴻海","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"鴻海","offsetgroup":"鴻海","orientation":"v","showlegend":true,"textposition":"auto","x":["鴻海"],"xaxis":"x","y":[4310149182.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{x}\u003cbr\u003e營收 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"台積電","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"台積電","offsetgroup":"台積電","orientation":"v","showlegend":true,"textposition":"auto","x":["台積電"],"xaxis":"x","y":[1536206985.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{x}\u003cbr\u003e營收 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"和碩","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"和碩","offsetgroup":"和碩","orientation":"v","showlegend":true,"textposition":"auto","x":["和碩"],"xaxis":"x","y":[914613914.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{x}\u003cbr\u003e營收 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"廣達","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"廣達","offsetgroup":"廣達","orientation":"v","showlegend":true,"textposition":"auto","x":["廣達"],"xaxis":"x","y":[797714951.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{x}\u003cbr\u003e營收 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"仁寶","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"仁寶","offsetgroup":"仁寶","orientation":"v","showlegend":true,"textposition":"auto","x":["仁寶"],"xaxis":"x","y":[705043628.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{x}\u003cbr\u003e營收 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"緯創","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"緯創","offsetgroup":"緯創","orientation":"v","showlegend":true,"textposition":"auto","x":["緯創"],"xaxis":"x","y":[636517435.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{x}\u003cbr\u003e營收 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"台塑化","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"台塑化","offsetgroup":"台塑化","orientation":"v","showlegend":true,"textposition":"auto","x":["台塑化"],"xaxis":"x","y":[536697941.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{x}\u003cbr\u003e營收 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"大聯大","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"大聯大","offsetgroup":"大聯大","orientation":"v","showlegend":true,"textposition":"auto","x":["大聯大"],"xaxis":"x","y":[488797875.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{x}\u003cbr\u003e營收 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"統一","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"統一","offsetgroup":"統一","orientation":"v","showlegend":true,"textposition":"auto","x":["統一"],"xaxis":"x","y":[433848346.0],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{x}\u003cbr\u003e營收 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"日月光投控","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"日月光投控","offsetgroup":"日月光投控","orientation":"v","showlegend":true,"textposition":"auto","x":["日月光投 ...

# %% [markdown]
# #### 5.繪製橫條圖分析

# %%
import plotly.express as px

# 確保 Net_Income_2024 是數值型態，處理千分位逗號（若有）
df["Net_Income_2024"] = df["Net_Income_2024"].astype(str).str.replace(",", "").astype(float)

# 取前 10 大企業（依 Revenue_2024 排序）
top10_companies = df.nlargest(10, "Revenue_2024")

# 繪製水平長條圖
fig = px.bar(top10_companies,
             x="Net_Income_2024",
             y="Company",
             orientation="h",
             title="前 10 大企業 2024 年淨利比較",
             labels={"Net_Income_2024": "淨利 (NTD)", "Company": "公司名稱"},
             color="Company")

fig.update_layout(yaxis=dict(categoryorder='total ascending'))  # 依照淨利由小到大排序

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e0314bdd-f982-4355-b8ca-81ca59d5287b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0314bdd-f982-4355-b8ca-81ca59d5287b")) {                    Plotly.newPlot(                        "e0314bdd-f982-4355-b8ca-81ca59d5287b",                        [{"alignmentgroup":"True","hovertemplate":"公司名稱=%{y}\u003cbr\u003e淨利 (NTD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"鴻海","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"鴻海","offsetgroup":"鴻海","orientation":"h","showlegend":true,"textposition":"auto","x":[117598322.0],"xaxis":"x","y":["鴻海"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{y}\u003cbr\u003e淨利 (NTD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"台積電","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"台積電","offsetgroup":"台積電","orientation":"h","showlegend":true,"textposition":"auto","x":[661261103.0],"xaxis":"x","y":["台積電"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{y}\u003cbr\u003e淨利 (NTD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"和碩","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"和碩","offsetgroup":"和碩","orientation":"h","showlegend":true,"textposition":"auto","x":[10294365.0],"xaxis":"x","y":["和碩"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{y}\u003cbr\u003e淨利 (NTD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"廣達","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"廣達","offsetgroup":"廣達","orientation":"h","showlegend":true,"textposition":"auto","x":[31742771.0],"xaxis":"x","y":["廣達"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{y}\u003cbr\u003e淨利 (NTD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"仁寶","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"仁寶","offsetgroup":"仁寶","orientation":"h","showlegend":true,"textposition":"auto","x":[8662511.0],"xaxis":"x","y":["仁寶"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{y}\u003cbr\u003e淨利 (NTD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"緯創","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"緯創","offsetgroup":"緯創","orientation":"h","showlegend":true,"textposition":"auto","x":[16855256.0],"xaxis":"x","y":["緯創"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{y}\u003cbr\u003e淨利 (NTD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"台塑化","marker":{"color":"#FF6692","pattern":{"shape":""}},"name":"台塑化","offsetgroup":"台塑化","orientation":"h","showlegend":true,"textposition":"auto","x":[15871887.0],"xaxis":"x","y":["台塑化"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{y}\u003cbr\u003e淨利 (NTD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"大聯大","marker":{"color":"#B6E880","pattern":{"shape":""}},"name":"大聯大","offsetgroup":"大聯大","orientation":"h","showlegend":true,"textposition":"auto","x":[7371671.0],"xaxis":"x","y":["大聯大"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{y}\u003cbr\u003e淨利 (NTD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"統一","marker":{"color":"#FF97FF","pattern":{"shape":""}},"name":"統一","offsetgroup":"統一","orientation":"h","showlegend":true,"textposition":"auto","x":[24119257.0],"xaxis":"x","y":["統一"],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"公司名稱=%{y}\u003cbr\u003e淨利 (NTD)=%{x}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"日月光投控","marker":{"color":"#FECB52","pattern":{"shape":""}},"name":"日月光投控","offsetgroup":"日月光投控","orientation":"h","showlegend":true,"textposition":"auto","x":[28513083.0],"xax ...

# %% [markdown]
# #### 6.繪製折線圖分析

# %%
import plotly.express as px
import pandas as pd

# 取出 EPS 相關數據
df_melted_eps = df.melt(id_vars=["Company"],
                         value_vars=["EPS_2023", "EPS_2024"],
                         var_name="Year",
                         value_name="EPS")

# 取前10大企業
top10_companies = df.groupby("Company")["Revenue_2024"].sum().nlargest(10).index
df_top10_eps = df_melted_eps[df_melted_eps["Company"].isin(top10_companies)]

# 繪製折線圖
fig = px.line(df_top10_eps,
              x="Year",
              y="EPS",
              color="Company",
              markers=True,
              title="前 10 大企業 EPS（每股盈餘）趨勢",
              labels={"EPS": "每股盈餘 (NTD)", "Year": "年度"})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="32815332-f99d-40b5-9ba8-81a1cf10d360" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32815332-f99d-40b5-9ba8-81a1cf10d360")) {                    Plotly.newPlot(                        "32815332-f99d-40b5-9ba8-81a1cf10d360",                        [{"hovertemplate":"Company=統一\u003cbr\u003e年度=%{x}\u003cbr\u003e每股盈餘 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"統一","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"統一","orientation":"v","showlegend":true,"x":["EPS_2023","EPS_2024"],"xaxis":"x","y":["2.95","3.09"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=台塑化\u003cbr\u003e年度=%{x}\u003cbr\u003e每股盈餘 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"台塑化","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"台塑化","orientation":"v","showlegend":true,"x":["EPS_2023","EPS_2024"],"xaxis":"x","y":["2.15","0.49"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=台積電\u003cbr\u003e年度=%{x}\u003cbr\u003e每股盈餘 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"台積電","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"台積電","orientation":"v","showlegend":true,"x":["EPS_2023","EPS_2024"],"xaxis":"x","y":["23.13","30.8"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=日月光投控\u003cbr\u003e年度=%{x}\u003cbr\u003e每股盈餘 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"日月光投控","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"日月光投控","orientation":"v","showlegend":true,"x":["EPS_2023","EPS_2024"],"xaxis":"x","y":["5.2","5.35"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=仁寶\u003cbr\u003e年度=%{x}\u003cbr\u003e每股盈餘 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"仁寶","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"仁寶","orientation":"v","showlegend":true,"x":["EPS_2023","EPS_2024"],"xaxis":"x","y":["1.35","1.86"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=廣達\u003cbr\u003e年度=%{x}\u003cbr\u003e每股盈餘 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"廣達","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"廣達","orientation":"v","showlegend":true,"x":["EPS_2023","EPS_2024"],"xaxis":"x","y":["7.63","11.37"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=緯創\u003cbr\u003e年度=%{x}\u003cbr\u003e每股盈餘 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"緯創","line":{"color":"#FF6692","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"緯創","orientation":"v","showlegend":true,"x":["EPS_2023","EPS_2024"],"xaxis":"x","y":["2.9","4.26"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=和碩\u003cbr\u003e年度=%{x}\u003cbr\u003e每股盈餘 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"和碩","line":{"color":"#B6E880","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"和碩","orientation":"v","showlegend":true,"x":["EPS_2023","EPS_2024"],"xaxis":"x","y":["4.02","4.93"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=大聯大\u003cbr\u003e年度=%{x}\u003cbr\u003e每股盈餘 (NTD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"大聯大","line":{"color":"#FF97FF","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"大聯大","orientation":"v","showlegend":true,"x":["EPS_2023","EPS_2024"],"xaxis":"x","y":["2.5","3.11"],"yaxis":"y","type":"scatter"},{"hovertemplate":"Company=鴻海\u003cbr\u003e年度=%{x}\u003cbr\u003e每股盈餘 (NTD)=%{y}\u ...

# %% [markdown]
# #### 7.Gemini AI 分析

# %%
prompt= f'我想請你把以下內容分析出哪家公司的財報比較好，包含營收成長、獲利能力、股價表現、財務穩健性等等來進行綜合評估{df.to_string()}並且用正體中文輸出給我'

# %%
from google.colab import userdata
apikey = userdata.get('test')

# %%
import google.generativeai as genai
genai.configure(api_key = apikey)
model = genai.GenerativeModel("gemini-1.5-flash")
response = model.generate_content(prompt)
print(response.text)
# Out:
# 根據提供的資料，要評估哪家公司的財報「最好」需要考量多個面向，並取決於投資人的風險承受能力和投資目標。單純比較數字無法得出絕對的結論，以下提供各公司在營收成長、獲利能力、股價表現（以EPS代表）、財務穩健性等方面的表現分析，供您參考：
#
#
# **營收成長:**
#
# * **表現優異:** 台泥 (30.41%)、東泥 (26.23%)、聯華 (5.25%)、炎洲 (36.05%)、遠東新 (5.23%)、新纖 (14.19%)、味全 (10.98%)、聯華食 (9.39%)、統一 (15.20%)、達新 (26.11%)、春源 (10.50%)、勤美 (15.35%)、中宇 (16.63%)、佳格 (3.27%)、再生-KY (14.29%)、富林-KY (6.31%)、南僑 (3.87%)、台塑化 (9.09%)、裕隆 (10.10%)、中華 (16.52%)、  華電 (9.64%)、華榮 (20.41%)、大亞 (15.85%)、中鋼 (26.11%)、豐祥-KY (0.89%)、南港 (123.46%)、台橡 (17.31%)、國際中橡 (5.03%)、豐達科 (16.44%)、三星 (7.28%)、士電 (7.40%)、中興電 (14.48%)、亞力 (2.29%)、力山 (29.31%)、華城 (57.34%)、東台 (28.99%)、  信大 (25.15%)、鈞興-KY (28.47%)、儒鴻 (22.28%)、聚陽 (10.01%)、佳和 (9.40%)、宏益 (48.87%)、台富 (5.43%)、集盛 (33.95%)、宜進 (11.77%)、聯發 (26.14%)、宏遠 (4.49%)、台南 (17.09%)、弘裕 (19.36%)、業旺 (55.39%)、東和鋼鐵 (1.57%)、燁興 (38.12%)、第一銅 (21.54%)、中鴻 (20.17%)、春雨 (5.80%)
� (-15.50%)、偉詮電 (7.98%)、超豐 (12.77%)、京元電子 (10.84%)、創見 (-2.87%)、聯發科 (29.18%)、義隆 (7.95%)、強茂 (-1.57%)、晶豪科 (18.47%)、聯陽 (3.44%)、嘉晶 (-2.42%)、聯詠 (-6.90%)、智原 (-11.26%)、揚智 (22.86%)、聯傑 (-33.29%)、鈺寶-創 (60.43%)、景碩 (16.28%)、世芯-KY (83.00%)、達能 (173.16%)、日月光投控 (2.80%)、新唐 (-8.28%)、凌通 (19.32%)、天鈺 (12.25%)、十銓 (53.34%)、立積 (31.62%)、全訊 (10.84%)、祥碩 (31.79%)、界霖 (-1.77%)、松翰 (6.74%)、盛群 (-14.16%)、力成 (9.36%)、迅杰 (-20.45%)、矽格 (15.99%)、同欣電 (8.28%)、矽力*-KY (19.77%)、億而得-創 (21.31%)、訊芯-KY (-9.87%)、穎崴 (41.54%)、捷敏-KY (5.26%)、達發 (37.54%)、愛普* (-3.16%)、晶心科 (41.17%)、易華電 (20.21%)、虹揚-KY (-20.38%)、芯鼎 (-14.94%)、力智 (23.80%)、威鋒電子 (-12.47%)、力積電 (2.23%)、采鈺 (36.52%)、來頡 (-9.57%)、錼創科技-KY創 (51.03%)、天虹 (17.30%)、矽創 (8.17%)、昇陽半導體 (-2.81%)、致新 (2.84%)、華東 (10.56%)、福懋科 (19.08%)、南茂 (10.66%)、微矽電子-創 (23.87%)、富鼎 (-1.53%)、宇瞻 (4.47%)、光寶科 (-11.30%)、全友 (30.41%)、仁寶 (-3.40%)、精英 (-14.44%)、佳世達 (-3.51%)、宏碁 (11.51%)、英業達 (15.98%)、華碩 (19.61%)、藍天 (9.15%)、倫飛 (17.49%)、昆盈 (31.35%)、技嘉 (118.84%)、微星 (9.40% ...
#
#
# **獲利能力 (以稅後淨利和營業利益來看):**
#
# 這部分需要更詳細的資料才能精準判斷，因為提供的資料中「非營業收入」和「非營業支出」項目影響淨利，而淨利率或毛利率等指標更能反映獲利能力。僅就提供的稅後淨利與前一年比較：
#
# * **稅後淨利大幅成長:**  嘉泥(282.37倍) 此數據需謹慎看待，因基期過低，可能具特殊原因，需進一步查證。 其餘公司成長率大多在合理的區間內，或呈現衰退。
#
#
# **股價表現 (以EPS代表):**
#
# * **表現優異:**  嘉泥(282.37倍) 同上，此數據需謹慎看待。 中興電(248.71倍)  此數據需謹慎看待，因基期過低，可能具特殊原因，需進一步查證。 其餘公司成長率大多在合理的區間內，或呈現衰退。
#
#
# **財務穩健性 (速動比率和流動比率):**
#
# 速動比率和流動比率越高，代表公司償債能力越好，財務越穩健。  各公司比率差異大，需個別分析：
#
# * **比率較高 (相對穩健):**  大多數公司比率在1以上，顯示短期償債能力尚可，但個別公司比率差異大，需要深入分析其產業特性及營運模式。
#
#
# **綜合評估:**
#
# 無法單純以財報數據判斷哪家公司最好，因為各公司屬於不同產業，營運模式、規模和成長階段都不同。  例如，營收成長率高的公司，可能伴隨著更高的風險；獲利能力強的公司，股價表現未必出色。
#
# **建議:**
#
# 1. **深入分析:**  選擇幾家感興趣的公司，進一步分析其財報，包括但不限於：
#     * **淨利率、毛利率:** 評估獲利能力
#     * **負債比率:** 評估財務風險
#     * **現金流量:** 評估營運現金流
#     * **產業趨勢:** 了解公司所處產業的發展前景
#     * **公司治理:**  評估公司的管理團隊和公司治理狀況
#
# 2. **比較分析:** 將選定公司在各個財務指標上的表現進行比較，並根據您的投資目標和風險承受能力做出最終的判斷。
#
# 3. **查閱專業報告:**  參考專業機構的投資報告，例如券商研究報告等，以獲得更全面的資訊。
#
# 4. **查核特殊數據:**  對於某些倍數變化極大的公司，例如嘉泥，需進一步調查原因，避免僅依單一數據做判斷。
#
#
# 總之，投資決策需要基於全面的分析和自身的風險承受能力，切勿單憑片面數據下結論。

# %%
from io import StringIO
df_all = pd.read_csv(StringIO(response.text))
df_all
# Out:
#    根據提供的資料，要評估哪家公司的財報「最好」需要考量多個面向，並取決於投資人的風險承受能力和投資目標。單純比較數字無法得出絕對的結論，以下提供各公司在營收成長、獲利能力、股價表現（以EPS代表）、財務穩健性等方面的表現分析，供您參考：
# 0                                           **營收成長:**
# 1   * **表現優異:** 台泥 (30.41%)、東泥 (26.23%)、聯華 (5.25%)...
# 2   * **表現不佳:** 亞泥 (-7.97%)、幸福 (-3.66%)、信大 (-23.64...
# 3                            **獲利能力 (以稅後淨利和營業利益來看):**
# 4   這部分需要更詳細的資料才能精準判斷，因為提供的資料中「非營業收入」和「非營業支出」項目影響淨...
# 5   * **稅後淨利大幅成長:**  嘉泥(282.37倍) 此數據需謹慎看待，因基期過低，可能...
# 6                                  **股價表現 (以EPS代表):**
# 7   * **表現優異:**  嘉泥(282.37倍) 同上，此數據需謹慎看待。 中興電(248....
# 8                              **財務穩健性 (速動比率和流動比率):**
# 9      速動比率和流動比率越高，代表公司償債能力越好，財務越穩健。  各公司比率差異大，需個別分析：
# 10  * **比率較高 (相對穩健):**  大多數公司比率在1以上，顯示短期償債能力尚可，但個別...
# 11                                          **綜合評估:**
# 12  無法單純以財報數據判斷哪家公司最好，因為各公司屬於不同產業，營運模式、規模和成長階段都不同。...
# 13                                            **建議:**
# 14          1. **深入分析:**  選擇幾家感興趣的公司，進一步分析其財報，包括但不限於：
# 15                              * **淨利率、毛利率:** 評估獲利能力
# 16                                 * **負債比率:** 評估財務風險
# 17                                * **現金流量:** 評估營運現金流
# 18                          * **產業趨勢:** 了解公司所處產業的發展前景
# 19                      * **公司治理:**  評估公司的管理團隊和公司治理狀況
# 20  2. **比較分析:** 將選定公司在各個財務指標上的表現進行比較，並根據您的投資目標和風險...
# 21   3. **查閱專業報告:**  參考專業機構的投資報告，例如券商研究報告等，以獲得更全面的資訊。
# 22  4. **查核特殊數據:**  對於某些倍數變化極大的公司，例如嘉泥，需進一步調查原因，避免...
# 23            總之，投資決策需要基於全面的分析和自身的風險承受能力，切勿單憑片面數據下結論。

# %% [markdown]
# #### 8. 回傳google sheet 紀錄

# %%
# 選擇要更新的工作表（選擇第一個工作表）
worksheet2 = gsheets.get_worksheet(2)  # 如果是其他工作表，可以用 get_worksheet(index)

# 將 DataFrame 寫入 Google Sheets
set_with_dataframe(worksheet2, df_all)
