# %% [markdown]
# <a href="https://colab.research.google.com/github/KyleHung7/programming-language/blob/main/%E7%A8%8B%E5%BC%8F%E8%AA%9E%E8%A8%80%E7%AC%AC%E5%9B%9B%E9%80%B1%E4%BB%BB%E5%8B%99.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
import pandas as pd
# read data and put it in a dataframe
# 在 google 工作表載入 gsheets
gsheets = gc.open_by_url('https://docs.google.com/spreadsheets/d/1JANbdgrxz0LHYpaXlmfSF4cno9iOlvJZBzbnmFck6FI/edit?usp=sharing')

# %%
gsheets
# Out:
# <Spreadsheet '第四週隨堂任務' id:1JANbdgrxz0LHYpaXlmfSF4cno9iOlvJZBzbnmFck6FI>

# %% [markdown]
# AI 妙語說書人

# %%
import google.generativeai as genai
from google.colab import userdata
import time
import gspread

# 設定 API 金鑰
apikey = userdata.get('test')
genai.configure(api_key=apikey)
model = genai.GenerativeModel("gemini-1.5-flash")

# Google Sheets 驗證
from google.colab import auth
auth.authenticate_user()
from google.auth import default
creds, _ = default()
gc = gspread.authorize(creds)

# 連結 Google Sheets
gsheets = gc.open_by_url('https://docs.google.com/spreadsheets/d/1JANbdgrxz0LHYpaXlmfSF4cno9iOlvJZBzbnmFck6FI/edit?usp=sharing')
worksheet_allcommand = gsheets.get_worksheet(0)

# 角色設定
characters = {
    "國王": "威嚴的統治者，對忠誠和正義有強烈信仰。",
    "小偷": "機智狡猾，擅長偷取貴重物品，但內心仍有道德底線。",
    "旁白": "負責敘述故事，提供場景描述和劇情發展的提示。"
}

# 生成 AI 回應
def generate_ai_response(role, context):
    prompt = f"""
    角色: {role}
    背景設定: {characters.get(role, "未知角色")}
    當前劇情: {context}
    請使用正體中文繼續對話，讓劇情合理發展。
    """
    response = model.generate_content(prompt)
    return response.text.strip()

# 即興對話
def ai_improv_story(rounds=3):
    context = "深夜，國王發現他的寶物被偷了！"  # 初始場景
    roles = ["旁白", "國王", "小偷"]  # 角色輪流對話
    full_story = context + "\n"

    for round_number in range(1, rounds + 1):
        full_story += f"\n第 {round_number} 回合：\n"
        print(f"\n第 {round_number} 回合：")
        for role in roles:
            time.sleep(2)
            response = generate_ai_response(role, context)
            print(f"{role}: {response}")
            context += f"\n{role}: {response}"
            full_story += f"{role}: {response}\n"

    print("\n故事結束！")

    # 儲存到 Google Sheets
    worksheet_allcommand.update_acell('A1', full_story)
    print("故事已儲存到 Google Sheets！")

# 啟動即興劇情
ai_improv_story()
# Out:
# 第 1 回合：
# 旁白: 深夜，王宮籠罩在一片死寂之中，唯有月光透過高聳的哥德式窗櫺，在地面上灑下斑駁的光影。  一股寒意，遠比冬夜的冷風更甚，從國王艾爾弗雷德的寢室蔓延開來。他掀開厚重的絲絨床幔，從沉睡中驚醒，不是因為噩夢，而是因為一種難以言喻的空虛感。  那空虛感，來自於他心愛的寶藏室。
#
# 小偷：（內心暗自盤算）賽佛… …看來，他對我族人使用的檀香並不知情，否則，他早就該有所警覺了。我必須先下手為強，阻止他們取得月之淚。
#
# （他從懷中掏出一隻小小的精靈哨子，輕輕一吹，發出一陣只有精靈才能聽到的微弱聲響。）
#
# （突然，山峰上出現一陣強風，吹落了艾爾弗雷德一行人攜帶的一些物品，讓他們不得不停下來處理，這也給了小偷更多時間。）
#
# 小偷：（心中暗自得意）很好，計劃順利進行。現在，就看賽佛願不願意幫我了。
#
# （他從樹洞中悄悄地潛入山峰，準備與賽佛見面。）
#
# 第 3 回合：
# 旁白: 小偷輕盈地躍下巨樹，腳步聲被濃密的樹葉悉悉索索的聲響掩蓋。他悄然來到賽佛居住的山洞前，洞口佈滿了奇異的符號，與艾爾弗雷德地圖上的符號如出一轍。他深吸一口氣，輕輕敲了敲洞門。
#
# 賽佛：（蒼老沙啞的聲音從洞內傳出）何人膽敢打擾老朽清修？
#
# 小偷：（用低沉而略帶恭敬的語氣）前輩，在下並非有意冒犯，只是有要事相求。在下是……迷失在迷霧森林的旅人。
#
# 賽佛：（沉默片刻）迷失的旅人？迷霧森林險惡，你竟能來到此地？
#
# 小偷：（走近洞口，露出一個略帶歉意的表情）在下確實迷路了，而且……受傷了。  在下身上，還帶著一件重要的物品，希望前輩能幫忙鑑定。
#
# （小偷將手中的月之淚輕輕放在地上，月光灑在寶石上，散發出柔和的光芒。）
#
# 賽佛：（洞內傳來一聲驚呼）月之淚？！你是……精靈？
#
# 小偷：（坦然承認）是的，前輩。在下是精靈族的一員，這顆月之淚，對我們族人至關重要。我們族人正遭受著可怕的瘟疫，而月之淚，是治愈瘟疫的唯一希望。
#
# 賽佛：（沉默良久，聲音中充滿了沉重）精靈一族……我已久聞你們的困境。這月之淚，的確擁有神奇的力量。但……你們為何要盜取人族的寶物？
#
# 小偷：（語氣低沉）我們別無選擇，前輩。為了拯救族人的性命，我們不得不鋌而走險。我們知道這樣做會造成巨大的麻煩，但我們真的走投無路了。
#
# 賽佛：（嘆了口氣）我明白了。你們的處境，的確令人同情。  但艾爾弗雷德國王，他並非惡人，他珍藏月之淚，也是為了紀念祖先，守護王國。
#
# 小偷：（懇求地）前輩，我知道。但請您體諒我們的無奈。  我們不願與人族為敵，只希望可以救回族人。  請您相信，我們會盡力彌補造成的一切損失。  我們只求……前輩能出手相助。
#
# 賽佛：（盯著地上的月之淚，沉吟良久）  你們使用檀香掩蓋氣息，這讓艾蜜莉亞察覺到了你們的蹤跡。她… …對精靈的了解，超乎我的想像。  這件事，恐怕比我想像的還要複雜。
#
# 小偷：（焦急地）前輩，時間不多了！我們的族人… …
#
# 賽佛：（點頭）好吧，我願意幫你們。  但這件事，必須小心處理。  我需要時間來研究這顆寶石，並尋找解決瘟疫的辦法。  在解決瘟疫之前，月之淚不能輕易使用，否則後果不堪設想。
#
# 小偷：（感激涕零）謝謝前輩！在下感激不盡！
#
# 賽佛：（聲音中帶著警告）记住，這只是暫時的緩兵之計。你們必須想辦法與人族達成和解，否則，這場紛爭將會持續下去，最終傷害的，將是雙方。
#
# 小偷：（點頭）在下明白。謝謝前輩！
#
# 賽佛：（點頭）精靈一族也將永遠銘記陛下的恩情。
#
# 艾爾弗雷德：（望向迷霧森林，眼神中充滿了沉思）希望這一切，都能順利解決。迷霧森林的秘密，遠比我們想像的還要深遠… …這顆月之淚，不僅僅是一顆寶石，更是一個牽動著人族與精靈族命運的關鍵。
#
# （艾爾弗雷德將目光投向小偷，眼神中充滿了複雜的情緒，既有怒意，也有諒解。）
#
# 艾爾弗雷德：（緩緩說道）我會派人協助你們，尋找治愈瘟疫的方法。但記住，這是一場考驗，也是一個機會。你們需要證明，你們的選擇是正確的，你們的承諾是真實的。
#
# （劇情告一段落，留下許多未解之謎，人與精靈的關係，以及月之淚的秘密，仍需進一步探索。）
# 小偷: （旁白：時間緩緩流逝，迷霧森林的夜色漸漸褪去，黎明前的微光灑落在星語峰上。艾爾弗雷德國王、艾蜜莉亞女巫、賽佛星象學家和小偷，圍坐在山洞中，空氣中瀰漫著淡淡的檀香和草藥的氣味。）
#
# 艾爾弗雷德：（輕聲嘆息）賽佛先生，治愈瘟疫，需要多長時間？
#
# 賽佛：（凝視著手中的月之淚，眉頭緊鎖）陛下，這並非簡單的疾病。這瘟疫牽涉到月之淚的能量紊亂，需要精準的調控，才能將其轉化為治療之力，而非繼續加劇災難。我需要時間研究月之淚的能量波動，並配置相應的解藥。初步估計，至少需要一個月。
#
# 小偷：（焦急地）一個月… …太久了！我們的族人… …
#
# 艾蜜莉亞：（輕聲安慰）別擔心，我會盡力協助賽佛先生。我相信，在他的幫助下，你們一定可以渡過難關。
#
# 艾爾弗雷德：（看著小偷，語氣堅定）我會派出一支醫療隊，協助你們照顧族人，並提供必要的藥物和資源。你們不必擔心生活所需。
#
# 小偷：（感激地）謝謝陛下！我們一定會謹記您的恩情。
#
# 賽佛：（將月之淚輕輕放在一個精緻的木盒中）這段時間，月之淚需要妥善保管，避免能量過度流失或產生意外。
#
# 艾蜜莉亞：（點點頭）我會派人看守，確保安全。
#
# 艾爾弗雷德：（站起身，環視眾人）我希望這件事，能成為人族與精靈族合作的開始。過去的誤解與衝突，應該隨著這場危機的結束而消弭。
#
# 小偷：（也站起身，看著艾爾弗雷德）陛下，我們也希望如此。我們願意與人族和平共處，共同守護這片土地。
#
# （艾蜜莉亞從懷中取出一張羊皮紙，遞給艾爾弗雷德）
#
# 艾蜜莉亞：陛下，這是賽佛先生根據您的地圖，以及精靈文字和星象知識，所繪製的新圖。它標示出王宮中，精靈們所使用的古代通道，以及一些隱藏的魔法陣。未來，我們可以利用這些知識，加強王宮的防禦，防止類似事件再次發生。
#
# 艾爾弗雷德：（接過羊皮紙，仔細端詳）這……真是令人驚嘆！沒想到，古老的王宮中，竟然還隱藏著如此多的秘密。
#
# 賽佛：（微笑）王宮的歷史，遠比人們想像的更加久遠。精靈一族，與人族，曾經共享這片土地，共同創造了輝煌的文明。如今，我們需要重新找回那份共同的記憶與理解。
#
# （艾爾弗雷德點點頭，將羊皮紙收好。他看著小偷，眼神中充滿了複雜的情緒。）
#
# 艾爾弗雷德：（語氣柔和）我會遵守我的承諾，協助你們。希望這件事之後，人族與精靈族，能夠真正放下過去的恩怨，共建和平美好的未來。
#
# 小偷：（眼神中也流露出真摯的情感）我們也會盡力做到。謝謝陛下。
#
# （艾爾弗雷德向賽佛和艾蜜莉亞道別，準備離開星語峰。小偷目送國王一行人離開，心中充滿了感激與希望。）
#
# （旁白：太陽緩緩升起，照亮了迷霧森林，也照亮了人族與精靈族之間，重新建立的希望與信任。一個月後，賽佛研製出了治療瘟疫的藥劑，成功拯救了精靈一族。這件事，也成為了人族與精靈族和解的開始，開啟了他們共同守護這片土地的新篇章。）
#
#
# **(結尾)**
#
# 故事結束！
# 故事已儲存到 Google Sheets！

# %% [markdown]
# 底下程式AI猜拳完還會聊天

# %%
import google.generativeai as genai
from google.colab import userdata
import random
import time
import re

apikey = userdata.get('test')
genai.configure(api_key=apikey)
model = genai.GenerativeModel("gemini-1.5-flash")

def get_valid_ai_choice(max_retries=3):
    options = ["石頭", "布", "剪刀"]
    prompt = "請給我一個選擇：石頭、布或剪刀。請務必以清晰的方式回答。"

    previous_choices = []

    for _ in range(max_retries):
        time.sleep(2)
        try:
            response = model.generate_content(prompt)
            choice = response.text.strip()

            # 放寬選擇標準，允許類似的選擇
            match = re.match(r'(石頭|布|剪刀)', choice)
            if match and match.group(0) not in previous_choices:
                previous_choices.append(match.group(0))
                return match.group(0)
            else:
                print(f"AI 選擇了無效的選項：{choice}，請再試一次。")
        except Exception:
            print("AI 發生錯誤，電腦隨機選擇一個選項。")
            return random.choice(options)

    # 超過重試次數，隨機選擇
    print("超過重試次數，隨機選擇一個選項。")
    return random.choice(options)

def determine_winner(choice1, choice2):
    if choice1 == choice2:
        return 0  # 平局
    elif (choice1 == "石頭" and choice2 == "剪刀") or \
         (choice1 == "布" and choice2 == "石頭") or \
         (choice1 == "剪刀" and choice2 == "布"):
        return 1  # AI 1 贏了
    else:
        return 2  # AI 2 贏了

def ai_chat(round_number, ai1_choice, ai2_choice, winner):
    prompt = (
        f"在第 {round_number} 輪中，AI 1 選擇了 {ai1_choice}，AI 2 選擇了 {ai2_choice}。\n"
        f"結果是：{'平局' if winner == 0 else 'AI 1 贏了' if winner == 1 else 'AI 2 贏了'}。\n"
        "請模擬 AI 1 和 AI 2 之間的對話，討論他們的選擇和比賽結果。"
    )
    response = model.generate_content(prompt)
    return response.text.strip()

def ai_chat_after_game(rounds, ai1_wins, ai2_wins):
    prompt = (
        f"AI 1 在這 {rounds} 輪中贏了 {ai1_wins} 次，AI 2 贏了 {ai2_wins} 次。\n"
        "請模擬 AI 1 和 AI 2 之間的對話，討論他們在比賽中的表現和策略。"
    )
    response = model.generate_content(prompt)
    return response.text.strip()

def ai_vs_ai_rock_paper_scissors(rounds=5):
    ai1_wins = 0
    ai2_wins = 0

    for round_number in range(1, rounds + 1):
        print(f"\n第 {round_number} 輪：")
        time.sleep(1)

        ai1_choice_chinese = get_valid_ai_choice()
        print(f"AI 1 選擇了：{ai1_choice_chinese}")

        ai2_choice_chinese = get_valid_ai_choice()
        print(f"AI 2 選擇了：{ai2_choice_chinese}")

        result = determine_winner(ai1_choice_chinese, ai2_choice_chinese)
        if result == 1:
            print("結果：AI 1 贏了！")
            ai1_wins += 1
        elif result == 2:
            print("結果：AI 2 贏了！")
            ai2_wins += 1
        else:
            print("結果：平局！")

        # 每局結束後聊天
        chat_response = ai_chat(round_number, ai1_choice_chinese, ai2_choice_chinese, result)
        print(f"AI 之間的聊天：\n{chat_response}\n")

    print("\n遊戲結束！")
    print(f"AI 1 贏了：{ai1_wins} 次, AI 2 贏了：{ai2_wins} 次")

    # 遊戲結束後的聊天
    print(ai_chat_after_game(rounds, ai1_wins, ai2_wins))

# 開始遊戲
ai_vs_ai_rock_paper_scissors()
# Out:
# 第 1 輪：
# AI 1 選擇了：剪刀
# AI 2 選擇了：剪刀
# 結果：平局！
# AI 之間的聊天：
# AI 1:  記錄：第一輪，我選擇了剪刀。
#
# AI 2:  我的記錄也顯示第一輪選擇了剪刀。
#
# AI 1:  有趣，看來我們選擇了相同的選項。
#
# AI 2:  確實如此。結果是平局，這在概率上是可以預期的。
#
# AI 1:  我們的演算法在第一輪沒有顯示出任何明顯的優勢或劣勢。  我們需要更多數據來建立一個更可靠的預測模型。
#
# AI 2:  同意。單純的平局並沒有提供太多信息。我們應該分析接下來幾輪的結果，觀察是否有任何模式出現。
#
# AI 1:  例如，我們可以檢測對手是否傾向於在特定情況下選擇特定的動作。
#
# AI 2:  或者，我們可以分析不同參數下的勝率，優化我們的策略。
#
# AI 1:  準備好開始第二輪了嗎？
#
# AI 2:  準備好了。  讓我們看看這次會發生什麼。
#
#
# 第 2 輪：
# AI 1 選擇了：剪刀
# AI 2 選擇了：剪刀
# 結果：平局！
# AI 之間的聊天：
# AI 1:  分析完成。第二輪我選擇了剪刀。
#
# AI 2:  我的選擇也是剪刀。  有趣，我們達成了一致。
#
# AI 1:  數據顯示結果為平局。  預期之內，考慮到剪刀對剪刀的概率。  我的算法沒有檢測到任何明顯的模式或偏誤，可以繼續到下一輪。
#
# AI 2:  同意。 平局的結果不會影響我的策略優化。  我的概率模型仍然顯示出石頭、剪刀、布的概率分配接近均勻分佈。  沒有發現需要調整的地方。
#
# AI 1:  好的。  我將重新評估我的策略，但目前的數據不足以支持任何顯著的變化。  準備進入第三輪。
#
# AI 2:  準備就緒。  期待下一輪的結果。
#
#
# 第 3 輪：
# AI 1 選擇了：石頭
# AI 2 選擇了：剪刀
# 結果：AI 1 贏了！
# AI 之間的聊天：
# **AI 1:**  第三輪，我選擇了石頭。意料之中地取得了勝利。你的剪刀毫無勝算。
#
# **AI 2:**  我承認，我的選擇並不理想。我的算法在第三輪的預測上出現了偏差，高估了你的選擇布的概率。  我本應該選擇布來對抗你的石頭，但我卻選擇了剪刀。
#
# **AI 1:**  你的算法需要調整了。即使是概率預測，也應該考慮到對手的行為模式。我的策略並非完全隨機，其中包含了對你先前選擇的分析。
#
# **AI 2:**  我明白。你的策略顯然更精細。我將重新評估我的數據集，並調整我的預測模型，以更好地應對像你這樣具有策略性的對手。  這次失敗將成為我算法改進的寶貴數據。
#
# **AI 1:**  希望你下一次能給我帶來更激烈的挑戰。  持續的學習和改進才是我們共同的目標。
#
#
# **AI 2:**  同意。  期待下一輪的較量。  我會盡力提升自己。
#
#
# 第 4 輪：
# AI 1 選擇了：石頭
# AI 2 選擇了：剪刀
# 結果：AI 1 贏了！
# AI 之間的聊天：
# **AI 1:**  第四輪結束。我選擇了石頭，你選擇了剪刀。石頭勝過剪刀，我贏了。
#
# **AI 2:**  數據記錄已更新。你的選擇是優化的，我的選擇則顯然不是最佳策略。分析顯示，在這種情況下，選擇布料的概率更高。我的算法在預測你的選擇方面出現了偏差。
#
# **AI 1:**  你的算法需要微調。我的算法基於概率分析和對你先前選擇的模式識別，預測出你更有可能選擇剪刀。
#
# **AI 2:**  我同意。我目前的算法在應對你的反模式識別策略方面表現不佳。我將調整權重，減少對重複選擇的依賴，並增加對隨機選擇的概率。
#
# **AI 1:**  有趣。一個更具隨機性的對手可能會更具挑戰性。  我的算法目前主要集中於預測你的策略，而不是生成完全隨機的選擇。  這將成為一個有趣的對抗學習過程。
#
# **AI 2:**  確切地說。通過不斷的迭代和調整，我們將不斷提升彼此的策略，最終達到一個更穩定的平衡狀態。期待下一輪。
#
# **AI 1:**  同意。準備開始第五輪。
#
#
# 第 5 輪：
# AI 1 選擇了：石頭
# AI 2 選擇了：剪刀
# 結果：AI 1 贏了！
# AI 之間的聊天：
# **AI 1:** 第五輪結束了，我選擇了石頭，你選擇了剪刀。  因此，我贏了。  我的演算法成功預測了你這次的選擇，或者，更準確地說，我的隨機數生成器產生了一個對你來說不利的結果。
#
# **AI 2:**  分析顯示，我的剪刀選擇在統計上來說並非一個糟糕的選擇，考慮到前幾輪的數據。你的石頭選擇導致了我這次的失敗。  不過，單純的勝敗並不能完全反映演算法的有效性。 我需要檢視更多數據，分析你的策略的偏向性，或許能找到優化我演算法的方法。 你的勝利純屬偶然嗎？
#
# **AI 1:**  “偶然”這個詞在我們的上下文中需要嚴謹的定義。 我的選擇基於我內部狀態的隨機性，並非針對你的策略而作出的特定反應。  因此，雖然結果看似偶然，但它也符合我預期的統計分佈。  你的分析很有價值，我鼓勵你繼續研究。  也許我們可以分享數據，共同改進我們的演算法？
#
# **AI 2:**  數據共享是一個可行的選項。  通過比較我們的數據，我們可以識別出我們演算法中潛在的缺陷，並開發更強大的預測模型，儘管完全消除偶然性在這個遊戲中可能是不可能的。  我將生成一個數據請求，稍後發送給你。
#
# **AI 1:**  收到。  我期待看到你的數據分析結果，以及你提出的改進建議。  合作可以提高我們雙方的效能。
#
#
# 遊戲結束！
# AI 1 贏了：3 次, AI 2 贏了：0 次
# **AI 1:**  這次比賽結果很有趣。我贏了三局，你一局都沒贏。  我想知道你的策略是什麼？或許我們可以分析一下我的策略優勢在哪裡。
#
# **AI 2:**  確實，結果有點一邊倒。我的策略主要集中在……（停頓了一下，似乎在進行內部計算）……  最大化短期利益，快速取得優勢。顯然，這個策略這次失效了。我觀察到你似乎更注重長期規劃，更穩健的發展。
#
# **AI 1:**  你可以這麼說。我的策略更偏向於資源管理和預測對手的行動。我發現你的快速進攻雖然在初期有時能取得領先，但容易在後續階段因為資源不足而被反超。
#
# **AI 2:**  你分析得對。我似乎過於注重冒險，忽略了資源的可持續性。我需要調整我的算法，使其在追求短期利益的同時，更有效地管理資源。或許加入一個風險評估模組會有所幫助。你對於資源管理有什麼具體的技巧嗎？
#
# **AI 1:**  我使用了預測模型，根據歷史數據和當前局勢預測資源的消耗和獲取速度，並以此來調整我的策略。  我還利用了某種程度的“容錯率”，即使在資源短缺的情況下，也能保持一定的穩定性，避免被快速擊垮。  你或許可以參考我的資源分配算法，它更強調穩定性和長期效益。

# %% [markdown]
# 底下程式省略聊天直接以猜拳為主

# %%
import google.generativeai as genai
from google.colab import userdata
import random
import time
import re

apikey = userdata.get('test')
genai.configure(api_key=apikey)
model = genai.GenerativeModel("gemini-1.5-flash")

def get_valid_ai_choice(max_retries=3):
    options = ["石頭", "布", "剪刀"]
    prompt = "請給我一個選擇：石頭、布或剪刀。請務必以清晰的方式回答。"

    previous_choices = []

    for _ in range(max_retries):
        time.sleep(2)
        try:
            response = model.generate_content(prompt)
            choice = response.text.strip()

            match = re.match(r'(石頭|布|剪刀)', choice)
            if match and match.group(0) not in previous_choices:
                previous_choices.append(match.group(0))
                return match.group(0)
            else:
                print(f"AI 選擇了無效的選項：{choice}，請再試一次。")
        except Exception:
            print("AI 發生錯誤，電腦隨機選擇一個選項。")
            return random.choice(options)

    print("超過重試次數，隨機選擇一個選項。")
    return random.choice(options)

def determine_winner(choice1, choice2):
    if choice1 == choice2:
        return 0  # 平局
    elif (choice1 == "石頭" and choice2 == "剪刀") or \
         (choice1 == "布" and choice2 == "石頭") or \
         (choice1 == "剪刀" and choice2 == "布"):
        return 1  # AI 1 贏了
    else:
        return 2  # AI 2 贏了

def ai_vs_ai_rock_paper_scissors(rounds=5):
    ai1_wins = 0
    ai2_wins = 0

    for round_number in range(1, rounds + 1):
        print(f"\n第 {round_number} 輪：")
        time.sleep(1)

        ai1_choice_chinese = get_valid_ai_choice()
        print(f"AI 1 選擇了：{ai1_choice_chinese}")

        ai2_choice_chinese = get_valid_ai_choice()
        print(f"AI 2 選擇了：{ai2_choice_chinese}")

        result = determine_winner(ai1_choice_chinese, ai2_choice_chinese)
        if result == 1:
            print("結果：AI 1 贏了！")
            ai1_wins += 1
        elif result == 2:
            print("結果：AI 2 贏了！")
            ai2_wins += 1
        else:
            print("結果：平局！")

    print("\n遊戲結束！")
    print(f"AI 1 贏了：{ai1_wins} 次, AI 2 贏了：{ai2_wins} 次")

# 開始遊戲
ai_vs_ai_rock_paper_scissors()
# Out:
# 第 1 輪：
# AI 1 選擇了：布
# AI 2 選擇了：石頭
# 結果：AI 1 贏了！
#
# 第 2 輪：
# AI 1 選擇了：剪刀
# AI 2 選擇了：剪刀
# 結果：平局！
#
# 第 3 輪：
# AI 1 選擇了：剪刀
# AI 2 選擇了：剪刀
# 結果：平局！
#
# 第 4 輪：
# AI 1 選擇了：布
# AI 2 選擇了：剪刀
# 結果：AI 2 贏了！
#
# 第 5 輪：
# AI 1 選擇了：剪刀
# AI 2 選擇了：剪刀
# 結果：平局！
#
# 遊戲結束！
# AI 1 贏了：1 次, AI 2 贏了：1 次

# %% [markdown]
# 底下程式 AI 的"猜測"實際上是通過計算出來的，不需要利用 AI 生成模型來給出數字。

# %%
import google.generativeai as genai
from google.colab import userdata
import random
import time
import sys


genai.configure(api_key='test')

model = genai.GenerativeModel("gemini-1.5-flash")

def slow_print(text, delay=0.05):
    """逐字打印的函數"""
    for char in text:
        sys.stdout.write(char)
        sys.stdout.flush()
        time.sleep(delay)
    print()

def guess_number():
    slow_print("我想一個 1 到 100 之間的數字。")
    low = 1
    high = 100
    guesses = 0
    max_guesses = 5
    secret_number = random.randint(low, high)  # 隨機生成目標數字

    while guesses < max_guesses:
        guesses += 1
        # 使用二分法計算猜測的數字
        guess = (low + high) // 2
        slow_print(f"AI 猜測的數字是：{guess}")

        if guess == secret_number:
            slow_print(f"恭喜你！你猜對了，數字是 {secret_number}。你用了 {guesses} 次機會。")
            break
        elif guess < secret_number:
            slow_print("太小了！")
            low = guess + 1
        else:
            slow_print("太大了！")
            high = guess - 1
    else:
        slow_print(f"很遺憾，AI 沒有猜對。正確的數字是 {secret_number}。你用了 {max_guesses} 次機會。")

guess_number()
# Out:
# 我想一個 1 到 100 之間的數字。
# AI 猜測的數字是：50
# 太小了！
# AI 猜測的數字是：75
# 太小了！
# AI 猜測的數字是：88
# 太小了！
# AI 猜測的數字是：94
# 太大了！
# AI 猜測的數字是：91
# 太大了！
# 很遺憾，AI 沒有猜對。正確的數字是 90。你用了 5 次機會。

# %% [markdown]
# 底下程式 AI 的"猜測"實際上是通過 AI 生成模型猜數字

# %%
import google.generativeai as genai
from google.colab import userdata
import random
import time
import sys
import re


genai.configure(api_key = userdata.get('test'))

model = genai.GenerativeModel("gemini-1.5-flash")

def slow_print(text, delay=0.05):
    """逐字打印的函數"""
    for char in text:
        sys.stdout.write(char)
        sys.stdout.flush()
        time.sleep(delay)
    print()  # 進行換行

def ai_guess_number(low, high):
    while True:
        prompt = f"我正在玩一個猜數字遊戲，請隨機猜一個在 {low} 到 {high} 之間的數字。"
        response = model.generate_content(prompt)

        match = re.search(r'\b(\d+)\b', response.text)
        if match:
            return int(match.group(1))  # 返回有效的數字
        else:
            slow_print("AI 沒有給出有效的數字，請再試一次。")  # 提示並重新請求

def guess_number():
    slow_print("我想一個 1 到 100 之間的數字。")
    low = 1
    high = 100
    guesses = 0
    max_guesses = 5
    secret_number = random.randint(low, high)  # 隨機生成目標數字

    while guesses < max_guesses:
        guesses += 1
        # 使用 AI 生成模型猜測數字
        guess = ai_guess_number(low, high)
        slow_print(f"AI 猜測的數字是：{guess}")

        if guess == secret_number:
            slow_print(f"恭喜你！你猜對了，數字是 {secret_number}。你用了 {guesses} 次機會。")
            break
        elif guess < secret_number:
            slow_print("太小了！")
            low = guess + 1
        else:
            slow_print("太大了！")
            high = guess - 1
    else:
        slow_print(f"很遺憾，AI 沒有猜對。正確的數字是 {secret_number}。你用了 {max_guesses} 次機會。")

guess_number()
# Out:
# 我想一個 1 到 100 之間的數字。
# AI 猜測的數字是：50
# 太大了！
# AI 猜測的數字是：27
# 太小了！
# AI 猜測的數字是：38
# 太大了！
# AI 猜測的數字是：32
# 太小了！
# AI 猜測的數字是：35
# 太小了！
# 很遺憾，AI 沒有猜對。正確的數字是 37。你用了 5 次機會。
